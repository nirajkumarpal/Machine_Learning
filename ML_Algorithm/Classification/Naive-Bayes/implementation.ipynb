# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/nirajkumarpal/Desktop/Machine_Learning/Datasets/play_tennis.csv')

# %%
df.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df = df.drop(columns=['day'])

# %%
df.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %% [markdown]
# # Problem 1
#
# # Outlook=summy, Temp=Hot , Humidity=High, Wind=Weak
# # Play or No Play?

# %% [markdown]
# # Solution
#
# # P(yes/sunny,hot,high,weak)=P(sunny/yes) * P(hot/yes) * P(High/yes) * P(weak/yes)
#
# # P(Nos/sunny,hot,high,weak)=P(sunny/No) * P(hot/No) * P(High/No) * P(weak/No)

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
Py = 9/14

Pn = 5/14

# %%
print(Py)
print(Pn)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %%
# outlook
pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
Pon = 0
Prn = 2/5
Psn = 3/5


Poy = 4/9
Pry = 3/9
Psy = 2/9

# %%
# temp

pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
PCoolNo=1/5
PHotNo=2/5
PMildNo=2/5

PCoolYes=3/9
PHotYes=2/9
PMildYes=4/9

# %%
# Humidity

pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
PHighNO=4/5
PNormalN0=1/5


PHighYes=3/9
PNormalYes=6/9

# %%
#wind
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
PStrongNo=3/5
PWeakNo=2/5

PStrongYes=3/9
PWeakYes=6/9

# %%
# Outlook=summy, Temp=Hot , Humidity=High, Wind=Weak

pyes = Py*Psy*PHotYes*PHighYes*PWeakYes
print(pyes)
# Out:
# 0.007054673721340388

# %%
pno = Pn*Psn*PHotNo*PHighNO*PWeakNo
print(pno)
# Out:
# 0.02742857142857143

# %%
# Result = No Play
